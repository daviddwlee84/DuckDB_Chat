# %% [markdown]
# # DuckDB + LangChain SQLDatabase
#
# [Unlocking ChatGPT's Potential: LangChain Tutorial with DuckDB - YouTube](https://www.youtube.com/watch?v=FoGm7d0paIo)
#
# ## Trouble Shooting and Issues
#
# - [Issue: db.get_usable_table_names() return nothing · Issue #4565 · langchain-ai/langchain](https://github.com/langchain-ai/langchain/issues/4565#issuecomment-1833391840)
# - [feat: parquet file support for SQL agent · Issue #2002 · langchain-ai/langchain](https://github.com/langchain-ai/langchain/issues/2002)

# %%
import duckdb

# %%
from sqlalchemy import create_engine

# %%
# uri = 'duckdb:///../demo/demo.duckdb'
# (sql_engine := create_engine(uri))

uri = 'duckdb:///:memory:'
# (sql_engine := create_engine(uri))

# %% [markdown]
# ## DuckDB Connect
#
# - [Python API - DuckDB](https://duckdb.org/docs/api/python/overview.html#using-an-in-memory-database)
# - [Connect - DuckDB](https://duckdb.org/docs/connect.html)

# %%
# (conn := duckdb.connect('../demo/demo.duckdb'))
(conn := duckdb.connect(':memory:'))

# %%
(df := conn.read_csv('../demo/demo.csv'))
# Out:
# ┌─────────┬─────────────┬──────────────────────┬──────────────────┬───────────┬───┬────────────┬──────────┬──────────────┬────────────┐
# │ Trade # │    Type     │        Signal        │    Date/Time     │ Price USD │ … │ Run-up USD │ Run-up % │ Drawdown USD │ Drawdown % │
# │  int64  │   varchar   │       varchar        │     varchar      │  double   │   │   double   │  double  │    double    │   double   │
# ├─────────┼─────────────┼──────────────────────┼──────────────────┼───────────┼───┼────────────┼──────────┼──────────────┼────────────┤
# │      23 │ Exit Long   │ Open                 │ NULL             │      NULL │ … │       NULL │     NULL │         NULL │       NULL │
# │      23 │ Entry Long  │ {'take_profit': 1.…  │ 2023-11-13 16:30 │   1.06932 │ … │       NULL │     NULL │         NULL │       NULL │
# │      22 │ Exit Long   │ exit                 │ 2023-11-10 22:50 │   1.06728 │ … │     203.72 │     0.01 │      2000.16 │        0.1 │
# │      22 │ Entry Long  │ {'take_profit': 1.…  │ 2023-11-10 22:45 │   1.06836 │ … │     203.72 │     0.01 │      2000.16 │        0.1 │
# │      21 │ Exit Long   │ exit                 │ 2023-11-10 17:45 │   1.06769 │ … │     2474.7 │     0.07 │        271.2 │       0.01 │
# │      21 │ Entry Long  │ {'take_profit': 1.…  │ 2023-11-10 17:40 │   1.06696 │ … │     2474.7 │     0.07 │        271.2 │       0.01 │
# │      20 │ Exit Short  │ exit                 │ 2023-11-08 22:30 │   1.06803 │ … │     138.72 │     0.01 │      2011.44 │       0.08 │
# │      20 │ Entry Short │ {'take_profit': 1.…  │ 2023-11-08 22:25 │   1.06716 │ … │     138.72 │     0.01 │      2011.44 │       0.08 │
# │      19 │ Exit Long   │ exit                 │ 2023-11-08 21:25 │   1.06646 │ … │      424.2 │     0.01 │       1999.8 │       0.06 │
# │      19 │ Entry Long  │ {'take_profit': 1.…  │ 2023-11-08 21:15 │   1.06712 │ … │      424.2 │     0.01 │       1999.8 │       0.06 │
# │       · │     ·       │  ·                   │        ·         │      ·    │ · │        ·   │       ·  │          ·   │         ·  │
# │       · │     ·       │  ·                   │        ·         │      ·    │ · │        ·   │       ·  │          ·   │         ·  │
# │       · │     ·       │  ·                   │        ·         │      ·    │ · │        ·   │       ·  │          ·   │         ·  │
# │       5 │ Exit Short  │ exit                 │ 2023-10-05 16:50 │   1.05029 │ … │    2463.39 │      0.1 │       878.04 │       0.03 │
# │       5 │ Entry Short │ {'take_profit': 1.…  │ 2023-10-05 16:15 │    1.0513 │ … │    2463.39 │      0.1 │       878.04 │       0.03 │
# │       4 │ Exit Long   │ exit                 │ 2023-10-04 11:45 │   1.04595 │ … │      575.4 │     0.02 │       2000.2 │       0.07 │
# │       4 │ Entry Long  │ {'take_profit': 1.…  │ 2023-10-04 09:50 │   1.04668 │ … │      575.4 │     0.02 │       2000.2 │       0.07 │
# │       3 │ Exit Short  │ exit                 │ 2023-09-29 21:25 │   1.05873 │ … │    2463.16 │     0.13 │      1259.36 │       0.06 │
# │       3 │ Entry Short │ {'take_profit': 1.…  │ 2023-09-29 20:50 │   1.06006 │ … │    2463.16 │     0.13 │      1259.36 │       0.06 │
# │       2 │ Exit Short  │ exit                 │ 2023-09-28 22:05 │   1.05556 │ … │     272.09 │     0.02 │      1999.27 │       0.16 │
# │       2 │ Entry Short │ {'take_profit': 1.…  │ 2023-09-28 21:45 │   1.05387 │ … │     272.09 │     0.02 │      1999.27 │       0.16 │
# │       1 │ Exit Short  │ exit                 │ 2023-09-27 21:25 │   1.05332 │ … │    2476.24 │      0.1 │      1285.74 │       0.05 │
# │       1 │ Entry Short │ {'take_profit': 1.…  │ 2023-09-27 21:05 │   1.05436 │ … │    2476.24 │      0.1 │      1285.74 │       0.05 │
# ├─────────┴─────────────┴──────────────────────┴──────────────────┴───────────┴───┴────────────┴──────────┴──────────────┴────────────┤
# │ 46 rows (20 shown)                                                                                             14 columns (9 shown) │
# └─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
conn.register('tbl', df)

# %%
conn.execute('DESCRIBE tbl;').df()
# Out:
#         column_name column_type null   key default  extra
# 0           Trade #      BIGINT  YES  None    None    NaN
# 1              Type     VARCHAR  YES  None    None    NaN
# 2            Signal     VARCHAR  YES  None    None    NaN
# 3         Date/Time     VARCHAR  YES  None    None    NaN
# 4         Price USD      DOUBLE  YES  None    None    NaN
# 5         Contracts      BIGINT  YES  None    None    NaN
# 6        Profit USD      DOUBLE  YES  None    None    NaN
# 7          Profit %      DOUBLE  YES  None    None    NaN
# 8   Cum. Profit USD      DOUBLE  YES  None    None    NaN
# 9     Cum. Profit %      DOUBLE  YES  None    None    NaN
# 10       Run-up USD      DOUBLE  YES  None    None    NaN
# 11         Run-up %      DOUBLE  YES  None    None    NaN
# 12     Drawdown USD      DOUBLE  YES  None    None    NaN
# 13       Drawdown %      DOUBLE  YES  None    None    NaN

# %%
conn.execute('SHOW TABLES;').df()
# Out:
#   name
# 0  tbl

# %% [markdown]
# ## LangChain SQLDatabase
#
# - [SQL Database | 🦜️🔗 Langchain](https://python.langchain.com/docs/integrations/toolkits/sql_database)

# %%
from langchain.sql_database import SQLDatabase

# %%
# This calls sqlalchemy create_engine under the hood
# (db := SQLDatabase.from_uri(uri, include_tables=['tbl']))
# (db := SQLDatabase.from_uri('duckdb:///:memory:'))
(db := SQLDatabase.from_uri(uri, sample_rows_in_table_info=3))

# %%
db.get_usable_table_names()
# Out:
# []

# %%
# conn.read_csv('../demo/demo.csv')

# %%
db.get_usable_table_names()
# Out:
# []

# %%
db.run('SELECT * FROM df;')
# db.run('SELECT * FROM tbl;') # this will fail
# Out:
# '[(23, \'Exit Long\', \'Open\', None, None, None, None, None, None, None, None, None, None, None), (23, \'Entry Long\', "{\'take_profit\': 1.0703532, \'stop_loss\': 1.06848, \'lots\': 23.81}", \'2023-11-13 16:30\', 1.06932, None, None, None, None, None, None, None, None, None), (22, \'Exit Long\', \'exit\', \'2023-11-10 22:50\', 1.06728, 1852000, -2000.16, -0.1, 9729.93, -0.2, 203.72, 0.01, 2000.16, 0.1), (22, \'Entry Long\', "{\'take_profit\': 1.0696884, \'stop_loss\': 1.06728, \'lots\': 18.52}", \'2023-11-10 22:45\', 1.06836, 1852000, -2000.16, -0.1, 9729.93, -0.2, 203.72, 0.01, 2000.16, 0.1), (21, \'Exit Long\', \'exit\', \'2023-11-10 17:45\', 1.06769, 3390000, 2474.7, 0.07, 11730.09, 0.25, 2474.7, 0.07, 271.2, 0.01), (21, \'Entry Long\', "{\'take_profit\': 1.0676857, \'stop_loss\': 1.06637, \'lots\': 33.9}", \'2023-11-10 17:40\', 1.06696, 3390000, 2474.7, 0.07, 11730.09, 0.25, 2474.7, 0.07, 271.2, 0.01), (20, \'Exit Short\', \'exit\', \'2023-11-08 22:30\', 1.06803, 2312000, -2011.44, -0.08, 9255.39, -0.2, 138.72, 0.01, 2011.44, 0.08), (20, \'Entry Short\', "{\'take_profit\': 1.06609605, \'stop_loss\': 1.068025, \'lots\' : 23.12}", \'2023-11-08 22:25\', 1.06716, 2312000, -2011.44, -0.08, 9255.39, -0.2, 138.72, 0.01, 2011.44, 0.08), (19, \'Exit Long\', \'exit\', \'2023-11-08 21:25\', 1.06646, 3030000, -1999.8, -0.06, 11266.83, -0.2, 424.2, 0.01, 1999.8, 0.06), (19, \'Entry Long\', "{\'take_profit\': 1.0679318, \'stop_loss\': 1.06646, \'lots\': 30.3}", \'2023-11-08 21:15\', 1.06712, 3030000, -1999.8, -0.06, 11266.83, -0.2, 424.2, 0.01, 1999.8, 0.06), (18, \'Exit Long\', \'exit\', \'2023-11-08 02:15\', 1.06874, 2857000, 2485.59, 0.08, 13266.63, 0.25, 2485.59, 0.08, 885.67, 0.03), (18, \'Entry Long\', "{\'take_profit\': 1.068731, \'stop_loss\': 1.06717, \'lots\': 28.57}", \'2023-11-08 01:55\', 1.06787, 2857000, 2485.59, 0.08, 13266.63, 0.25, 2485.59, 0.08, 885.67, 0.03), (17, \'Exit Short\', \'exit\', \'2023-11-03 14:35\', 1.06334, 1613000, -2000.12, -0.12, 10781.04, -0.2, 983.93, 0.06, 2000.12, 0.12), (17, \'Entry Short\', "{\'take_profit\': 1.0605748, \'stop_loss\': 1.06334, \'lots\' : 16.13}", \'2023-11-03 06:00\', 1.0621, 1613000, -2000.12, -0.12, 10781.04, -0.2, 983.93, 0.06, 2000.12, 0.12), (16, \'Exit Short\', \'exit\', \'2023-11-02 03:05\', 1.05534, 943000, -1999.16, -0.2, 12781.16, -0.2, 1471.08, 0.15, 1999.16, 0.2), (16, \'Entry Short\', "{\'take_profit\': 1.0506124, \'stop_loss\': 1.05534, \'lots\' : 9.43}", \'2023-11-02 02:15\', 1.05322, 943000, -1999.16, -0.2, 12781.16, -0.2, 1471.08, 0.15, 1999.16, 0.2), (15, \'Exit Long\', \'exit\', \'2023-10-30 23:05\', 1.06139, 1869000, 2467.08, 0.12, 14780.32, 0.24, 2467.08, 0.12, 205.59, 0.01), (15, \'Entry Long\', "{\'take_profit\': 1.0613861, \'stop_loss\': 1.059, \'lots\': 18.69}", \'2023-10-30 22:45\', 1.06007, 1869000, 2467.08, 0.12, 14780.32, 0.24, 2467.08, 0.12, 205.59, 0.01), (14, \'Exit Long\', \'exit\', \'2023-10-30 19:40\', 1.05875, 3125000, 2468.75, 0.07, 12313.24, 0.24, 2468.75, 0.07, 1937.5, 0.06), (14, \'Entry Long\', "{\'take_profit\': 1.0587472, \'stop_loss\': 1.05732, \'lots\': 31.25}", \'2023-10-30 19:05\', 1.05796, 3125000, 2468.75, 0.07, 12313.24, 0.24, 2468.75, 0.07, 1937.5, 0.06), (13, \'Exit Short\', \'exit\', \'2023-10-30 15:25\', 1.05585, 4545000, 2499.75, 0.05, 9844.49, 0.25, 2499.75, 0.05, 863.55, 0.02), (13, \'Entry Short\', "{\'take_profit\': 1.0558588, \'stop_loss\': 1.05684, \'lots\' : 45.45}", \'2023-10-30 15:10\', 1.0564, 4545000, 2499.75, 0.05, 9844.49, 0.25, 2499.75, 0.05, 863.55, 0.02), (12, \'Exit Short\', \'exit\', \'2023-10-24 20:00\', 1.06332, 5000000, 2500.0, 0.05, 7344.74, 0.25, 2500.0, 0.05, 1750.0, 0.03), (12, \'Entry Short\', "{\'take_profit\': 1.063328, \'stop_loss\': 1.06422, \'lots\' : 50}", \'2023-10-24 19:45\', 1.06382, 5000000, 2500.0, 0.05, 7344.74, 0.25, 2500.0, 0.05, 1750.0, 0.03), (11, \'Exit Long\', \'exit\', \'2023-10-16 19:55\', 1.05373, 3774000, 2490.84, 0.06, 4844.74, 0.25, 2490.84, 0.06, 679.32, 0.02), (11, \'Entry ...

# %%
db.get_table_info()
# Out:
# ''

# %% [markdown]
# ## Try DuckDBLoader
#
# - [DuckDB | 🦜️🔗 Langchain](https://python.langchain.com/docs/integrations/document_loaders/duckdb)

# %%
from langchain.document_loaders import DuckDBLoader

# %%
(loader := DuckDBLoader("SELECT * FROM read_csv_auto('../demo/demo.csv')"))

# %%
(data := loader.load())
# Out:
# [Document(page_content='Trade #: 23\nType: Exit Long\nSignal: Open\nDate/Time: None\nPrice USD: None\nContracts: None\nProfit USD: None\nProfit %: None\nCum. Profit USD: None\nCum. Profit %: None\nRun-up USD: None\nRun-up %: None\nDrawdown USD: None\nDrawdown %: None'),
#  Document(page_content="Trade #: 23\nType: Entry Long\nSignal: {'take_profit': 1.0703532, 'stop_loss': 1.06848, 'lots': 23.81}\nDate/Time: 2023-11-13 16:30\nPrice USD: 1.06932\nContracts: None\nProfit USD: None\nProfit %: None\nCum. Profit USD: None\nCum. Profit %: None\nRun-up USD: None\nRun-up %: None\nDrawdown USD: None\nDrawdown %: None"),
#  Document(page_content='Trade #: 22\nType: Exit Long\nSignal: exit\nDate/Time: 2023-11-10 22:50\nPrice USD: 1.06728\nContracts: 1852000\nProfit USD: -2000.16\nProfit %: -0.1\nCum. Profit USD: 9729.93\nCum. Profit %: -0.2\nRun-up USD: 203.72\nRun-up %: 0.01\nDrawdown USD: 2000.16\nDrawdown %: 0.1'),
#  Document(page_content="Trade #: 22\nType: Entry Long\nSignal: {'take_profit': 1.0696884, 'stop_loss': 1.06728, 'lots': 18.52}\nDate/Time: 2023-11-10 22:45\nPrice USD: 1.06836\nContracts: 1852000\nProfit USD: -2000.16\nProfit %: -0.1\nCum. Profit USD: 9729.93\nCum. Profit %: -0.2\nRun-up USD: 203.72\nRun-up %: 0.01\nDrawdown USD: 2000.16\nDrawdown %: 0.1"),
#  Document(page_content='Trade #: 21\nType: Exit Long\nSignal: exit\nDate/Time: 2023-11-10 17:45\nPrice USD: 1.06769\nContracts: 3390000\nProfit USD: 2474.7\nProfit %: 0.07\nCum. Profit USD: 11730.09\nCum. Profit %: 0.25\nRun-up USD: 2474.7\nRun-up %: 0.07\nDrawdown USD: 271.2\nDrawdown %: 0.01'),
#  Document(page_content="Trade #: 21\nType: Entry Long\nSignal: {'take_profit': 1.0676857, 'stop_loss': 1.06637, 'lots': 33.9}\nDate/Time: 2023-11-10 17:40\nPrice USD: 1.06696\nContracts: 3390000\nProfit USD: 2474.7\nProfit %: 0.07\nCum. Profit USD: 11730.09\nCum. Profit %: 0.25\nRun-up USD: 2474.7\nRun-up %: 0.07\nDrawdown USD: 271.2\nDrawdown %: 0.01"),
#  Document(page_content='Trade #: 20\nType: Exit Short\nSignal: exit\nDate/Time: 2023-11-08 22:30\nPrice USD: 1.06803\nContracts: 2312000\nProfit USD: -2011.44\nProfit %: -0.08\nCum. Profit USD: 9255.39\nCum. Profit %: -0.2\nRun-up USD: 138.72\nRun-up %: 0.01\nDrawdown USD: 2011.44\nDrawdown %: 0.08'),
#  Document(page_content="Trade #: 20\nType: Entry Short\nSignal: {'take_profit': 1.06609605, 'stop_loss': 1.068025, 'lots' : 23.12}\nDate/Time: 2023-11-08 22:25\nPrice USD: 1.06716\nContracts: 2312000\nProfit USD: -2011.44\nProfit %: -0.08\nCum. Profit USD: 9255.39\nCum. Profit %: -0.2\nRun-up USD: 138.72\nRun-up %: 0.01\nDrawdown USD: 2011.44\nDrawdown %: 0.08"),
#  Document(page_content='Trade #: 19\nType: Exit Long\nSignal: exit\nDate/Time: 2023-11-08 21:25\nPrice USD: 1.06646\nContracts: 3030000\nProfit USD: -1999.8\nProfit %: -0.06\nCum. Profit USD: 11266.83\nCum. Profit %: -0.2\nRun-up USD: 424.2\nRun-up %: 0.01\nDrawdown USD: 1999.8\nDrawdown %: 0.06'),
#  Document(page_content="Trade #: 19\nType: Entry Long\nSignal: {'take_profit': 1.0679318, 'stop_loss': 1.06646, 'lots': 30.3}\nDate/Time: 2023-11-08 21:15\nPrice USD: 1.06712\nContracts: 3030000\nProfit USD: -1999.8\nProfit %: -0.06\nCum. Profit USD: 11266.83\nCum. Profit %: -0.2\nRun-up USD: 424.2\nRun-up %: 0.01\nDrawdown USD: 1999.8\nDrawdown %: 0.06"),
#  Document(page_content='Trade #: 18\nType: Exit Long\nSignal: exit\nDate/Time: 2023-11-08 02:15\nPrice USD: 1.06874\nContracts: 2857000\nProfit USD: 2485.59\nProfit %: 0.08\nCum. Profit USD: 13266.63\nCum. Profit %: 0.25\nRun-up USD: 2485.59\nRun-up %: 0.08\nDrawdown USD: 885.67\nDrawdown %: 0.03'),
#  Document(page_content="Trade #: 18\nType: Entry Long\nSignal: {'take_profit': 1.068731, 'stop_loss': 1.06717, 'lots': 28.57}\nDate/Time: 2023-11-08 01:55\nPrice USD: 1.06787\nContracts: 2857000\nProfit USD: 2485.59\nProfit %: 0.08\nCum. Profit USD: 13266.63\nCum. Profit %: 0.25\nRun-up USD: 2485.59\nRun-up %: 0.08\nDrawdown USD: 885.67\nDrawdown %: 0.03"),
#  Document(page_content='Trade #: 17\nType: Exit Short\nSignal: exit\nDate/Time: 2023-11-03 14:35\nPrice USD: 1.06334\nContracts: 1613000\nProfit USD: -2000.12\nProfit %: -0.12\nCum. Profit USD: 10781.04\nCum. Profit %: -0.2\nRun-up USD: 983.93\nRun-up %: 0.06\nDrawdown USD: 2000.12\nDrawdown %: 0.12'),
#  Document(page_content="Trade #: 17\nType: Entry Short\nSignal: {'take_profit': 1.0605748, 'stop_loss': 1.06334, 'lots' : 16.13}\nDate/Time: 2023-11-03 06:00\nPrice USD: 1.0621\nContracts: 1613000\nProfit USD: -2000.12\nProfit %: -0.12\nCum. Profit USD: 10781.04\nCum. Profit %: -0.2\nRun-up USD: 983.93\nRun-up %: 0.06\nDrawdown USD: 2000.12\nDrawdown %: 0.12"),
#  Document(page_content='Trade #: 16\nType: Exit Short\nSignal: exit\nDate/Time: 2023-11-02 03:05\nPrice USD: 1.05534\nContracts: 943000\nProfit USD: -1999.16\nProfit %: -0.2\nCum. Profit USD: 12781.16\nCum. Profit %: -0.2\nRun-up USD: 1471.08\nRun-up %: 0.15\nDrawdown USD: 1999.16\nDrawdown %: 0.2'),
#  Document(page_content="Trade #: 16\nType: Entry Short\nSignal: {'take_profit': 1.0506124, 'stop_loss': 1.05534, 'lots' : 9.43}\nDate/Time: 2023-11-02 02:15\nPrice USD: 1.05322\nContracts: 943000\nProfit USD: -1999.16\nProfit %: -0.2\nCum. Profit USD: 12781.16\nCum. Profit %: -0.2\nRun-up USD: 1471.08\nRun-up %: 0.15\nDrawdown USD: 1999.16\nDrawdown %: 0.2"),
#  Document(page_content='Trade #: 15\nType: Exit Long\nSignal: exit\nDate/Time: 2023-10-30 23:05\nPrice USD: 1.06139\nContracts: 1869000\nProfit USD: 2467.08\nProfit %: 0.12\nCum. Profit USD: 14780.32\nCum. Profit %: 0.24\nRun-up USD: 2467.08\nRun-up %: 0.12\nDrawdown USD: 205.59\nDrawdown %: 0.01'),
#  Document(page_content="Trade #: 15\nType: Entry Long\nSignal: {'take_profit': 1.0613861, 'stop_loss': 1.059, 'lots': 18.69}\nDate/Time: 2023-10-30 22:45\nPrice USD: 1.06007\nContracts: 1869000\nProfit USD: 2467.08\nProfit %: 0.12\nCum. Profit USD: 14780.32\nCum. Profit %: 0.24\nRun-up USD: 2467.08\nRun-up %: 0.12\nDrawdown USD: 205.59\nDrawdown %: 0.01"),
#  Document(page_content='Trade #: 14\nType: Exit Long\nSignal: exit\nDate/Time: 2023-10-30 19:40\nPrice USD: 1.05875\nContracts: 3125000\nProfit USD: 2468.75\nProfit %: 0.07\nCum. Profit USD: 12313.24\nCum. Profit %: 0.24\nRun-up USD: 2468.75\nRun-up %: 0.07\nDrawdown USD: 1937.5\nDrawdown %: 0.06'),
#  Document(page_content="Trade #: 14\nType: Entry Long\nSignal: {'take_profit': 1.0587472, 'stop_loss': 1.05732, 'lots': 31.25}\nDate/Time: 2023-10-30 19:05\nPrice USD: 1.05796\nContracts: 3125000\nProfit USD: 2468.75\nProfit %: 0.07\nCum. Profit USD: 12313.24\nCum. Profit %: 0.24\nRun-up USD: 2468.75\nRun-up %: 0.07\nDrawdown USD: 1937.5\nDrawdown %: 0.06"),
#  Document(page_content='Trade #: 13\nType: Exit Short\nSignal: exit\nDate/Time: 2023-10-30 15:25\nPrice USD: 1.05585\nContracts: 4545000\nProfit USD: 2499.75\nProfit %: 0.05\nCum. Profit USD: 9844.49\nCum. Profit %: 0.25\nRun-up USD: 2499.75\nRun-up %: 0.05\nDrawdown USD: 863.55\nDrawdown %: 0.02'),
#  Document(page_content="Trade #: 13\nType: Entry Short\nSignal: {'take_profit': 1.0558588, 'stop_loss': 1.05684, 'lots' : 45.45}\nDate/Time: 2023-10-30 15:10\nPrice USD: 1.0564\nContracts: 4545000\nProfit USD: 2499.75\nProfit %: 0.05\nCum. Profit USD: 9844.49\nCum. Profit %: 0.25\nRun-up USD: 2499.75\nRun-up %: 0.05\nDrawdown USD: 863.55\nDrawdown %: 0.02"),
#  Document(page_content='Trade #: 12\nType: Exit Short\nSignal: exit\nDate/Time: 2023-10-24 20:00\nPrice USD: 1.06332\nContracts: 5000000\nProfit USD: 2500.0\nProfit %: 0.05\nCum. Profit USD: 7344.74\nCum. Profit %: 0.25\nRun-up USD: 2500.0\nRun-up %: 0.05\nDrawdown USD: 1750.0\nDrawdown %: 0.03'),
#  Document(page_content="Trade #: 12\nType: Entry Short\nSignal: {'take_profit': 1.063328, 'stop_loss': 1.06422, 'lots' : 50}\nDate/Time: 2023-10-24 19:45\nPrice USD: 1.06382\nContracts: 5000000\nProfit USD: 2500.0\nProfit %: 0.05\nCum. Profit USD: 7344.74\nCum. Profit %: 0.25\nRun-up USD: 2500.0\nRun-up %: 0.05\nDrawdown USD: 1750.0\nDrawdown %: 0.03"),
#  Document(page_content='Trade #: 11\nType: Exit Long\nSignal: exit\nDate/Time: 2023-10-16 19:55\nPrice USD: 1.05373\nContracts: 3774000\nProfit USD: 2490.84\nProfit %: 0.06\nCum. Profit USD: 4844.74\nCum. Profit %: 0.25\nRun-up USD: 2490.84\nRun-up %: 0.06\nDrawdown USD: 679.32\nDrawdown %: 0.02'),
#  Document(page_content="Trade #: 11\nType: Entry Long\nSignal: {'take_profit': 1.0537219, 'stop_loss': 1.05254, 'lots': 37.74}\nDate/Time: 2023-10-16 19:20\nPrice USD: 1.05307\nContracts: 3774000\nProfit USD: 2490.84\nProfit %: 0.06\nCum. Profit USD: 4844.74\nCum. Profit %: 0.25\nRun-up USD: 2490.84\nRun-up %: 0.06\nDrawdown USD: 679.32\nDrawdown %: 0.02"),
#  Document(page_content='Trade #: 10\nType: Exit Long\nSignal: exit\nDate/Time: 2023-10-16 16:45\nPrice USD: 1.05394\nContracts: 2703000\nProfit USD: 2486.76\nProfit %: 0.09\nCum. Profit USD: 2353.9\nCum. Profit %: 0.25\nRun-up USD: 2486.76\nRun-up %: 0.09\nDrawdown USD: 1811.01\nDrawdown %: 0.06'),
#  Document(page_content="Trade #: 10\nType: Entry Long\nSignal: {'take_profit': 1.0539302, 'stop_loss': 1.05228, 'lots': 27.03}\nDate/Time: 2023-10-16 15:35\nPrice USD: 1.05302\nContracts: 2703000\nProfit USD: 2486.76\nProfit %: 0.09\nCum. Profit USD: 2353.9\nCum. Profit %: 0.25\nRun-up USD: 2486.76\nRun-up %: 0.09\nDrawdown USD: 1811.01\nDrawdown %: 0.06"),
#  Document(page_content='Trade #: 9\nType: Exit Short\nSignal: exit\nDate/Time: 2023-10-13 20:20\nPrice USD: 1.05316\nContracts: 2632000\nProfit USD: -2000.32\nProfit %: -0.07\nCum. Profit USD: -132.86\nCum. Profit %: -0.2\nRun-up USD: 789.6\nRun-up %: 0.03\nDrawdown USD: 2000.32\nDrawdown %: 0.07'),
#  Document(page_content="Trade #: 9\nType: Entry Short\nSignal: {'take_profit': 1.0514652, 'stop_loss': 1.05316, 'lots' : 26.32}\nDate/Time: 2023-10-13 20:10\nPrice USD: 1.0524\nContracts: 2632000\nProfit USD: -2000.32\nProfit %: -0.07\nCum. Profit USD: -132.86\nCum. Profit %: -0.2\nRun-up USD: 789.6\nRun-up %: 0.03\nDrawdown USD: 2000.32\nDrawdown %: 0.07"),
#  Document(page_content='Trade #: 8\nType: Exit Short\nSignal: exit\nDate/Time: 2023-10-11 21:25\nPrice USD: 1.06192\nContracts: 1852000\nProfit USD: -2000.16\nProfit %: -0.1\nCum. Profit USD: 1867.46\nCum. Profit %: -0.2\nRun-up USD: 222.24\nRun-up %: 0.01\nDrawdown USD: 2000.16\nDrawdown %: 0.1'),
#  Document(page_content="Trade #: 8\nType: Entry Short\nSignal: {'take_profit': 1.0595116, 'stop_loss': 1.06192, 'lots' : 18.52}\nDate/Time: 2023-10-11 21:15\nPrice USD: 1.06084\nContracts: 1852000\nProfit USD: -2000.16\nProfit %: -0.1\nCum. Profit USD: 1867.46\nCum. Profit %: -0.2\nRun-up USD: 222.24\nRun-up %: 0.01\nDrawdown USD: 2000.16\nDrawdown %: 0.1"),
#  Document(page_content='Trade #: 7\nType: Exit Short\nSignal: exit\nDate/Time: 2023-10-10 14:30\nPrice USD: 1.05547\nContracts: 2899000\nProfit USD: 2464.15\nProfit %: 0.08\nCum. Profit USD: 3867.62\nCum. Profit %: 0.25\nRun-up USD: 2464.15\nRun-up %: 0.08\nDrawdown USD: 173.94\nDrawdown %: 0.01'),
#  Document(page_content="Trade #: 7\nType: Entry Short\nSignal: {'take_profit': 1.0554713, 'stop_loss': 1.05701, 'lots' : 28.99}\nDate/Time: 2023-10-10 14:10\nPrice USD: 1.05632\nContracts: 2899000\nProfit USD: 2464.15\nProfit %: 0.08\nCum. Profit USD: 3867.62\nCum. Profit %: 0.25\nRun-up USD: 2464.15\nRun-up %: 0.08\nDrawdown USD: 173.94\nDrawdown %: 0.01"),
#  Document(page_content='Trade #: 6\nType: Exit Long\nSignal: exit\nDate/Time: 2023-10-10 00:55\nPrice USD: 1.05352\nContracts: 4255000\nProfit USD: -1999.85\nProfit %: -0.04\nCum. Profit USD: 1403.47\nCum. Profit %: -0.2\nRun-up USD: 808.45\nRun-up %: 0.02\nDrawdown USD: 1999.85\nDrawdown %: 0.04'),
#  Document(page_content="Trade #: 6\nType: Entry Long\nSignal: {'take_profit': 1.0545681, 'stop_loss': 1.05352, 'lots': 42.55}\nDate/Time: 2023-10-10 00:25\nPrice USD: 1.05399\nContracts: 4255000\nProfit USD: -1999.85\nProfit %: -0.04\nCum. Profit USD: 1403.47\nCum. Profit %: -0.2\nRun-up USD: 808.45\nRun-up %: 0.02\nDrawdown USD: 1999.85\nDrawdown %: 0.04"),
#  Document(page_content='Trade #: 5\nType: Exit Short\nSignal: exit\nDate/Time: 2023-10-05 16:50\nPrice USD: 1.05029\nContracts: 2439000\nProfit USD: 2463.39\nProfit %: 0.1\nCum. Profit USD: 3403.32\nCum. Profit %: 0.25\nRun-up USD: 2463.39\nRun-up %: 0.1\nDrawdown USD: 878.04\nDrawdown %: 0.03'),
#  Document(page_content="Trade #: 5\nType: Entry Short\nSignal: {'take_profit': 1.0502914, 'stop_loss': 1.05212, 'lots' : 24.39}\nDate/Time: 2023-10-05 16:15\nPrice USD: 1.0513\nContracts: 2439000\nProfit USD: 2463.39\nProfit %: 0.1\nCum. Profit USD: 3403.32\nCum. Profit %: 0.25\nRun-up USD: 2463.39\nRun-up %: 0.1\nDrawdown USD: 878.04\nDrawdown %: 0.03"),
#  Document(page_content='Trade #: 4\nType: Exit Long\nSignal: exit\nDate/Time: 2023-10-04 11:45\nPrice USD: 1.04595\nContracts: 2740000\nProfit USD: -2000.2\nProfit %: -0.07\nCum. Profit USD: 939.93\nCum. Profit %: -0.2\nRun-up USD: 575.4\nRun-up %: 0.02\nDrawdown USD: 2000.2\nDrawdown %: 0.07'),
#  Document(page_content="Trade #: 4\nType: Entry Long\nSignal: {'take_profit': 1.0475779, 'stop_loss': 1.04595, 'lots': 27.4}\nDate/Time: 2023-10-04 09:50\nPrice USD: 1.04668\nContracts: 2740000\nProfit USD: -2000.2\nProfit %: -0.07\nCum. Profit USD: 939.93\nCum. Profit %: -0.2\nRun-up USD: 575.4\nRun-up %: 0.02\nDrawdown USD: 2000.2\nDrawdown %: 0.07"),
#  Document(page_content='Trade #: 3\nType: Exit Short\nSignal: exit\nDate/Time: 2023-09-29 21:25\nPrice USD: 1.05873\nContracts: 1852000\nProfit USD: 2463.16\nProfit %: 0.13\nCum. Profit USD: 2940.13\nCum. Profit %: 0.25\nRun-up USD: 2463.16\nRun-up %: 0.13\nDrawdown USD: 1259.36\nDrawdown %: 0.06'),
#  Document(page_content="Trade #: 3\nType: Entry Short\nSignal: {'take_profit': 1.0587316, 'stop_loss': 1.06114, 'lots' : 18.52}\nDate/Time: 2023-09-29 20:50\nPrice USD: 1.06006\nContracts: 1852000\nProfit USD: 2463.16\nProfit %: 0.13\nCum. Profit USD: 2940.13\nCum. Profit %: 0.25\nRun-up USD: 2463.16\nRun-up %: 0.13\nDrawdown USD: 1259.36\nDrawdown %: 0.06"),
#  Document(page_content='Trade #: 2\nType: Exit Short\nSignal: exit\nDate/Time: 2023-09-28 22:05\nPrice USD: 1.05556\nContracts: 1183000\nProfit USD: -1999.27\nProfit %: -0.16\nCum. Profit USD: 476.97\nCum. Profit %: -0.2\nRun-up USD: 272.09\nRun-up %: 0.02\nDrawdown USD: 1999.27\nDrawdown %: 0.16'),
#  Document(page_content="Trade #: 2\nType: Entry Short\nSignal: {'take_profit': 1.0517913, 'stop_loss': 1.05556, 'lots' : 11.83}\nDate/Time: 2023-09-28 21:45\nPrice USD: 1.05387\nContracts: 1183000\nProfit USD: -1999.27\nProfit %: -0.16\nCum. Profit USD: 476.97\nCum. Profit %: -0.2\nRun-up USD: 272.09\nRun-up %: 0.02\nDrawdown USD: 1999.27\nDrawdown %: 0.16"),
#  Document(page_content='Trade #: 1\nType: Exit Short\nSignal: exit\nDate/Time: 2023-09-27 21:25\nPrice USD: 1.05332\nContracts: 2381000\nProfit USD: 2476.24\nProfit %: 0.1\nCum. Profit USD: 2476.24\nCum. Profit %: 0.25\nRun-up USD: 2476.24\nRun-up %: 0.1\nDrawdown USD: 1285.74\nDrawdown %: 0.05'),
#  Document(page_content="Trade #: 1\nType: Entry Short\nSignal: {'take_profit': 1.0533268, 'stop_loss': 1.0552, 'lots' : 23.81}\nDate/Time: 2023-09-27 21:05\nPrice USD: 1.05436\nContracts: 2381000\nProfit USD: 2476.24\nProfit %: 0.1\nCum. Profit USD: 2476.24\nCum. Profit %: 0.25\nRun-up USD: 2476.24\nRun-up %: 0.1\nDrawdown USD: 1285.74\nDrawdown %: 0.05")]

# %% [markdown]
# ## Workarounds (not directly use DuckDB)

# %% [markdown]
# ### Workaround: DuckDB => SQLite => SQLDatabase
#
# - [feat: parquet file support for SQL agent · Issue #2002 · langchain-ai/langchain](https://github.com/langchain-ai/langchain/issues/2002)

# %%
# Create from scratch
# conn.execute("""
# ATTACH '../demo/sqlite_database.db' AS sqlite_db (TYPE SQLITE);
# CREATE TABLE sqlite_db.tbl(id INTEGER, name VARCHAR);
# INSERT INTO sqlite_db.tbl VALUES (42, 'DuckDB');
# """)

conn.execute("""
ATTACH '../demo/sqlite_database.db' AS sqlite_db (TYPE SQLITE);
CREATE TABLE sqlite_db.tbl AS SELECT * FROM tbl;
""")

# %%
conn.execute("SELECT * FROM sqlite_db.tbl;").df()
# Out:
#     Trade #         Type                                             Signal  \
# 0        23    Exit Long                                               Open
# 1        23   Entry Long  {'take_profit': 1.0703532, 'stop_loss': 1.0684...
# 2        22    Exit Long                                               exit
# 3        22   Entry Long  {'take_profit': 1.0696884, 'stop_loss': 1.0672...
# 4        21    Exit Long                                               exit
# 5        21   Entry Long  {'take_profit': 1.0676857, 'stop_loss': 1.0663...
# 6        20   Exit Short                                               exit
# 7        20  Entry Short  {'take_profit': 1.06609605, 'stop_loss': 1.068...
# 8        19    Exit Long                                               exit
# 9        19   Entry Long  {'take_profit': 1.0679318, 'stop_loss': 1.0664...
# 10       18    Exit Long                                               exit
# 11       18   Entry Long  {'take_profit': 1.068731, 'stop_loss': 1.06717...
# 12       17   Exit Short                                               exit
# 13       17  Entry Short  {'take_profit': 1.0605748, 'stop_loss': 1.0633...
# 14       16   Exit Short                                               exit
# 15       16  Entry Short  {'take_profit': 1.0506124, 'stop_loss': 1.0553...
# 16       15    Exit Long                                               exit
# 17       15   Entry Long  {'take_profit': 1.0613861, 'stop_loss': 1.059,...
# 18       14    Exit Long                                               exit
# 19       14   Entry Long  {'take_profit': 1.0587472, 'stop_loss': 1.0573...
# 20       13   Exit Short                                               exit
# 21       13  Entry Short  {'take_profit': 1.0558588, 'stop_loss': 1.0568...
# 22       12   Exit Short                                               exit
# 23       12  Entry Short  {'take_profit': 1.063328, 'stop_loss': 1.06422...
# 24       11    Exit Long                                               exit
# 25       11   Entry Long  {'take_profit': 1.0537219, 'stop_loss': 1.0525...
# 26       10    Exit Long                                               exit
# 27       10   Entry Long  {'take_profit': 1.0539302, 'stop_loss': 1.0522...
# 28        9   Exit Short                                               exit
# 29        9  Entry Short  {'take_profit': 1.0514652, 'stop_loss': 1.0531...
# 30        8   Exit Short                                               exit
# 31        8  Entry Short  {'take_profit': 1.0595116, 'stop_loss': 1.0619...
# 32        7   Exit Short                                               exit
# 33        7  Entry Short  {'take_profit': 1.0554713, 'stop_loss': 1.0570...
# 34        6    Exit Long                                               exit
# 35        6   Entry Long  {'take_profit': 1.0545681, 'stop_loss': 1.0535...
# 36        5   Exit Short                                               exit
# 37        5  Entry Short  {'take_profit': 1.0502914, 'stop_loss': 1.0521...
# 38        4    Exit Long                                               exit
# 39        4   Entry Long  {'take_profit': 1.0475779, 'stop_loss': 1.0459...
# 40        3   Exit Short                                               exit
# 41        3  Entry Short  {'take_profit': 1.0587316, 'stop_loss': 1.0611...
# 42        2   Exit Short                                               exit
# 43        2  Entry Short  {'take_profit': 1.0517913, 'stop_loss': 1.0555...
# 44        1   Exit Short                                               exit
# 45        1  Entry Short  {'take_profit': 1.0533268, 'stop_loss': 1.0552...
#
#            Date/Time  Price USD  Contracts  Profit USD  Profit %  \
# 0               None        NaN        NaN         NaN       NaN
# 1   2023-11-13 16:30    1.06932        NaN         NaN       NaN
# 2   2023-11-10 22:50    1.06728  1852000.0    -2000.16     -0.10
# 3   2023-11-10 22:45    1.06836  1852000.0    -2000.16     -0.10
# 4   2023-11-10 17:45    1.06769  3390000.0     2474.70      0.07
# 5   2023-11-10 17:40    1.06696  3390000.0     2474.70      0.07
# 6   2023-11-08 22:30    1.06803  2312000.0    -2011.44     -0.08
# 7   2023-11-08 22:25    1.06716  2312000.0    -2011.44     -0.08
# 8   2023-11-08 21:25    1.06646  3030000.0    -1999.80     -0.06
# 9   2023-11-08 21:15    1.06712  3030000.0    -1999.80     -0.06
# 10  2023-11-08 02:15    1.06874  2857000.0     2485.59      0.08
# 11  2023-11-08 01:55    1.06787  2857000.0     2485.59      0.08
# 12  2023-11-03 14:35    1.06334  1613000.0    -2000.12     -0.12
# 13  2023-11-03 06:00    1.06210  1613000.0    -2000.12     -0.12
# 14  2023-11-02 03:05    1.05534   943000.0    -1999.16     -0.20
# 15  2023-11-02 02:15    1.05322   943000.0    -1999.16     -0.20
# 16  2023-10-30 23:05    1.06139  1869000.0     2467.08      0.12
# 17  2023-10-30 22:45    1.06007  1869000.0     2467.08      0.12
# 18  2023-10-30 19:40    1.05875  3125000.0     2468.75      0.07
# 19  2023-10-30 19:05    1.05796  3125000.0     2468.75      0.07
# 20  2023-10-30 15:25    1.05585  4545000.0     2499.75      0.05
# 21  2023-10-30 15:10    1.05640  4545000.0     2499.75      0.05
# 22  2023-10-24 20:00    1.06332  5000000.0     2500.00      0.05
# 23  2023-10-24 19:45    1.06382  5000000.0     2500.00      0.05
# 24  2023-10-16 19:55    1.05373  3774000.0     2490.84      0.06
# 25  2023-10-16 19:20    1.05307  3774000.0     2490.84      0.06
# 26  2023-10-16 16:45    1.05394  2703000.0     2486.76      0.09
# 27  2023-10-16 15:35    1.05302  2703000.0     2486.76      0.09
# 28  2023-10-13 20:20    1.05316  2632000.0    -2000.32     -0.07
# 29  2023-10-13 20:10    1.05240  2632000.0    -2000.32     -0.07
# 30  2023-10-11 21:25    1.06192  1852000.0    -2000.16     -0.10
# 31  2023-10-11 21:15    1.06084  1852000.0    -2000.16     -0.10
# 32  2023-10-10 14:30    1.05547  2899000.0     2464.15      0.08
# 33  2023-10-10 14:10    1.05632  2899000.0     2464.15      0.08
# 34  2023-10-10 00:55    1.05352  4255000.0    -1999.85     -0.04
# 35  2023-10-10 00:25    1.05399  4255000.0    -1999.85     -0.04
# 36  2023-10-05 16:50    1.05029  2439000.0     2463.39      0.10
# 37  2023-10-05 16:15    1.05130  2439000.0     2463.39      0.10
# 38  2023-10-04 11:45    1.04595  2740000.0    -2000.20     -0.07
# 39  2023-10-04 09:50    1.04668  2740000.0    -2000.20     -0.07
# 40  2023-09-29 21:25    1.05873  1852000.0     2463.16      0.13
# 41  2023-09-29 20:50    1.06006  1852000.0     2463.16      0.13
# 42  2023-09-28 22:05    1.05556  1183000.0    -1999.27     -0.16
# 43  2023-09-28 21:45    1.05387  1183000.0    -1999.27     -0.16
# 44  2023-09-27 21:25    1.05332  2381000.0     2476.24      0.10
# 45  2023-09-27 21:05    1.05436  2381000.0     2476.24      0.10
#
#     Cum. Profit USD  Cum. Profit %  Run-up USD  Run-up %  Drawdown USD  \
# 0               NaN            NaN         NaN       NaN           NaN
# 1               NaN            NaN         NaN       NaN           NaN
# 2           9729.93          -0.20      203.72      0.01       2000.16
# 3           9729.93          -0.20      203.72      0.01       2000.16
# 4          11730.09           0.25     2474.70      0.07        271.20
# 5          11730.09           0.25     2474.70      0.07        271.20
# 6           9255.39          -0.20      138.72      0.01       2011.44
# 7           9255.39          -0.20      138.72      0.01       2011.44
# 8          11266.83          -0.20      424.20      0.01       1999.80
# 9          11266.83          -0.20      424.20      0.01       1999.80
# 10         13266.63           0.25     2485.59      0.08        885.67
# 11         13266.63           0.25     2485.59      0.08        885.67
# 12         10781.04          -0.20      983.93      0.06       2000.12
# 13         10781.04          -0.20      983.93      0.06       2000.12
# 14         12781.16          -0.20     1471.08      0.15       1999.16
# 15         12781.16          -0.20     1471.08      0.15       1999.16
# 16         14780.32           0.24     2467.08      0.12        205.59
# 17         14780.32           0.24     2467.08      0.12        205.59
# 18         12313.24           0.24     2468.75      0.07       1937.50
# 19         12313.24           0.24     2468.75      0.07       1937.50
# 20          9844.49           0.25     2499.75      0.05        863.55
# 21          9844.49           0.25     2499.75      0.05        863.55
# 22          7344.74           0.25     2500.00      0.05       1750.00
# 23          7344.74           0.25     2500.00      0.05       1750.00
# 24          4844.74           0.25     2490.84      0.06        679.32
# 25          4844.74           0.25     2490.84      0.06        679.32
# 26          2353.90           0.25     2486.76      0.09       1811.01
# 27          2353.90           0.25     2486.76      0.09       1811.01
# 28          -132.86          -0.20      789.60      0.03       2000.32
# 29          -132.86          -0.20      789.60      0.03       2000.32
# 30          1867.46          -0.20      222.24      0.01       2000.16
# 31          1867.46          -0.20      222.24      0.01       2000.16
# 32          3867.62           0.25     2464.15      0.08        173.94
# 33          3867.62           0.25     2464.15      0.08        173.94
# 34          1403.47          -0.20      808.45      0.02       1999.85
# 35          1403.47          -0.20      808.45      0.02       1999.85
# 36          3403.32           0.25     2463.39      0.10        878.04
# 37          3403.32           0.25     2463.39      0.10        878.04
# 38           939.93          -0.20      575.40      0.02       2000.20
# 39           939.93          -0.20      575.40      0.02       2000.20
# 40          2940.13           0.25     2463.16      0.13       1259.36
# 41          2940.13           0.25     2463.16      0.13       1259.36
# 42           476.97          -0.20      272.09      0.02       1999.27
# 43           476.97          -0.20      272.09      0.02       1999.27
# 44          2476.24           0.25     2476.24      0.10       1285.74
# 45          2476.24           0.25     2476.24      0.10       1285.74
#
#     Drawdown %
# 0          NaN
# 1          NaN
# 2         0.10
# 3         0.10
# 4         0.01
# 5         0.01
# 6         0.08
# 7         0.08
# 8         0.06
# 9         0.06
# 10        0.03
# 11        0.03
# 12        0.12
# 13        0.12
# 14        0.20
# 15        0.20
# 16        0.01
# 17        0.01
# 18        0.06
# 19        0.06
# 20        0.02
# 21        0.02
# 22        0.03
# 23        0.03
# 24        0.02
# 25        0.02
# 26        0.06
# 27        0.06
# 28        0.07
# 29        0.07
# 30        0.10
# 31        0.10
# 32        0.01
# 33        0.01
# 34        0.04
# 35        0.04
# 36        0.03
# 37        0.03
# 38        0.07
# 39        0.07
# 40        0.06
# 41        0.06
# 42        0.16
# 43        0.16
# 44        0.05
# 45        0.05

# %%
import sqlite3

# %%
(sconn := sqlite3.connect('../demo/sqlite_database.db'))

# %%
sconn.execute('SELECT * FROM tbl;').fetchall()
# Out:
# [(23,
#   'Exit Long',
#   'Open',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (23,
#   'Entry Long',
#   "{'take_profit': 1.0703532, 'stop_loss': 1.06848, 'lots': 23.81}",
#   '2023-11-13 16:30',
#   1.06932,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (22,
#   'Exit Long',
#   'exit',
#   '2023-11-10 22:50',
#   1.06728,
#   1852000,
#   -2000.16,
#   -0.1,
#   9729.93,
#   -0.2,
#   203.72,
#   0.01,
#   2000.16,
#   0.1),
#  (22,
#   'Entry Long',
#   "{'take_profit': 1.0696884, 'stop_loss': 1.06728, 'lots': 18.52}",
#   '2023-11-10 22:45',
#   1.06836,
#   1852000,
#   -2000.16,
#   -0.1,
#   9729.93,
#   -0.2,
#   203.72,
#   0.01,
#   2000.16,
#   0.1),
#  (21,
#   'Exit Long',
#   'exit',
#   '2023-11-10 17:45',
#   1.06769,
#   3390000,
#   2474.7,
#   0.07,
#   11730.09,
#   0.25,
#   2474.7,
#   0.07,
#   271.2,
#   0.01),
#  (21,
#   'Entry Long',
#   "{'take_profit': 1.0676857, 'stop_loss': 1.06637, 'lots': 33.9}",
#   '2023-11-10 17:40',
#   1.06696,
#   3390000,
#   2474.7,
#   0.07,
#   11730.09,
#   0.25,
#   2474.7,
#   0.07,
#   271.2,
#   0.01),
#  (20,
#   'Exit Short',
#   'exit',
#   '2023-11-08 22:30',
#   1.06803,
#   2312000,
#   -2011.44,
#   -0.08,
#   9255.39,
#   -0.2,
#   138.72,
#   0.01,
#   2011.44,
#   0.08),
#  (20,
#   'Entry Short',
#   "{'take_profit': 1.06609605, 'stop_loss': 1.068025, 'lots' : 23.12}",
#   '2023-11-08 22:25',
#   1.06716,
#   2312000,
#   -2011.44,
#   -0.08,
#   9255.39,
#   -0.2,
#   138.72,
#   0.01,
#   2011.44,
#   0.08),
#  (19,
#   'Exit Long',
#   'exit',
#   '2023-11-08 21:25',
#   1.06646,
#   3030000,
#   -1999.8,
#   -0.06,
#   11266.83,
#   -0.2,
#   424.2,
#   0.01,
#   1999.8,
#   0.06),
#  (19,
#   'Entry Long',
#   "{'take_profit': 1.0679318, 'stop_loss': 1.06646, 'lots': 30.3}",
#   '2023-11-08 21:15',
#   1.06712,
#   3030000,
#   -1999.8,
#   -0.06,
#   11266.83,
#   -0.2,
#   424.2,
#   0.01,
#   1999.8,
#   0.06),
#  (18,
#   'Exit Long',
#   'exit',
#   '2023-11-08 02:15',
#   1.06874,
#   2857000,
#   2485.59,
#   0.08,
#   13266.63,
#   0.25,
#   2485.59,
#   0.08,
#   885.67,
#   0.03),
#  (18,
#   'Entry Long',
#   "{'take_profit': 1.068731, 'stop_loss': 1.06717, 'lots': 28.57}",
#   '2023-11-08 01:55',
#   1.06787,
#   2857000,
#   2485.59,
#   0.08,
#   13266.63,
#   0.25,
#   2485.59,
#   0.08,
#   885.67,
#   0.03),
#  (17,
#   'Exit Short',
#   'exit',
#   '2023-11-03 14:35',
#   1.06334,
#   1613000,
#   -2000.12,
#   -0.12,
#   10781.04,
#   -0.2,
#   983.93,
#   0.06,
#   2000.12,
#   0.12),
#  (17,
#   'Entry Short',
#   "{'take_profit': 1.0605748, 'stop_loss': 1.06334, 'lots' : 16.13}",
#   '2023-11-03 06:00',
#   1.0621,
#   1613000,
#   -2000.12,
#   -0.12,
#   10781.04,
#   -0.2,
#   983.93,
#   0.06,
#   2000.12,
#   0.12),
#  (16,
#   'Exit Short',
#   'exit',
#   '2023-11-02 03:05',
#   1.05534,
#   943000,
#   -1999.16,
#   -0.2,
#   12781.16,
#   -0.2,
#   1471.08,
#   0.15,
#   1999.16,
#   0.2),
#  (16,
#   'Entry Short',
#   "{'take_profit': 1.0506124, 'stop_loss': 1.05534, 'lots' : 9.43}",
#   '2023-11-02 02:15',
#   1.05322,
#   943000,
#   -1999.16,
#   -0.2,
#   12781.16,
#   -0.2,
#   1471.08,
#   0.15,
#   1999.16,
#   0.2),
#  (15,
#   'Exit Long',
#   'exit',
#   '2023-10-30 23:05',
#   1.06139,
#   1869000,
#   2467.08,
#   0.12,
#   14780.32,
#   0.24,
#   2467.08,
#   0.12,
#   205.59,
#   0.01),
#  (15,
#   'Entry Long',
#   "{'take_profit': 1.0613861, 'stop_loss': 1.059, 'lots': 18.69}",
#   '2023-10-30 22:45',
#   1.06007,
#   1869000,
#   2467.08,
#   0.12,
#   14780.32,
#   0.24,
#   2467.08,
#   0.12,
#   205.59,
#   0.01),
#  (14,
#   'Exit Long',
#   'exit',
#   '2023-10-30 19:40',
#   1.05875,
#   3125000,
#   2468.75,
#   0.07,
#   12313.24,
#   0.24,
#   2468.75,
#   0.07,
#   1937.5,
#   0.06),
#  (14,
#   'Entry Long',
#   "{'take_profit': 1.0587472, 'stop_loss': 1.05732, 'lots': 31.25}",
#   '2023-10-30 19:05',
#   1.05796,
#   3125000,
#   2468.75,
#   0.07,
#   12313.24,
#   0.24,
#   2468.75,
#   0.07,
#   1937.5,
#   0.06),
#  (13,
#   'Exit Short',
#   'exit',
#   '2023-10-30 15:25',
#   1.05585,
#   4545000,
#   2499.75,
#   0.05,
#   9844.49,
#   0.25,
#   2499.75,
#   0.05,
#   863.55,
#   0.02),
#  (13,
#   'Entry Short',
#   "{'take_profit': 1.0558588, 'stop_loss': 1.05684, 'lots' : 45.45}",
#   '2023-10-30 15:10',
#   1.0564,
#   4545000,
#   2499.75,
#   0.05,
#   9844.49,
#   0.25,
#   2499.75,
#   0.05,
#   863.55,
#   0.02),
#  (12,
#   'Exit Short',
#   'exit',
#   '2023-10-24 20:00',
#   1.06332,
#   5000000,
#   2500.0,
#   0.05,
#   7344.74,
#   0.25,
#   2500.0,
#   0.05,
#   1750.0,
#   0.03),
#  (12,
#   'Entry Short',
#   "{'take_profit': 1.063328, 'stop_loss': 1.06422, 'lots' : 50}",
#   '2023-10-24 19:45',
#   1.06382,
#   5000000,
#   2500.0,
#   0.05,
#   7344.74,
#   0.25,
#   2500.0,
#   0.05,
#   1750.0,
#   0.03),
#  (11,
#   'Exit Long',
#   'exit',
#   '2023-10-16 19:55',
#   1.05373,
#   3774000,
#   2490.84,
#   0.06,
#   4844.74,
#   0.25,
#   2490.84,
#   0.06,
#   679.32,
#   0.02),
#  (11,
#   'Entry Long',
#   "{'take_profit': 1.0537219, 'stop_loss': 1.05254, 'lots': 37.74}",
#   '2023-10-16 19:20',
#   1.05307,
#   3774000,
#   2490.84,
#   0.06,
#   4844.74,
#   0.25,
#   2490.84,
#   0.06,
#   679.32,
#   0.02),
#  (10,
#   'Exit Long',
#   'exit',
#   '2023-10-16 16:45',
#   1.05394,
#   2703000,
#   2486.76,
#   0.09,
#   2353.9,
#   0.25,
#   2486.76,
#   0.09,
#   1811.01,
#   0.06),
#  (10,
#   'Entry Long',
#   "{'take_profit': 1.0539302, 'stop_loss': 1.05228, 'lots': 27.03}",
#   '2023-10-16 15:35',
#   1.05302,
#   2703000,
#   2486.76,
#   0.09,
#   2353.9,
#   0.25,
#   2486.76,
#   0.09,
#   1811.01,
#   0.06),
#  (9,
#   'Exit Short',
#   'exit',
#   '2023-10-13 20:20',
#   1.05316,
#   2632000,
#   -2000.32,
#   -0.07,
#   -132.86,
#   -0.2,
#   789.6,
#   0.03,
#   2000.32,
#   0.07),
#  (9,
#   'Entry Short',
#   "{'take_profit': 1.0514652, 'stop_loss': 1.05316, 'lots' : 26.32}",
#   '2023-10-13 20:10',
#   1.0524,
#   2632000,
#   -2000.32,
#   -0.07,
#   -132.86,
#   -0.2,
#   789.6,
#   0.03,
#   2000.32,
#   0.07),
#  (8,
#   'Exit Short',
#   'exit',
#   '2023-10-11 21:25',
#   1.06192,
#   1852000,
#   -2000.16,
#   -0.1,
#   1867.46,
#   -0.2,
#   222.24,
#   0.01,
#   2000.16,
#   0.1),
#  (8,
#   'Entry Short',
#   "{'take_profit': 1.0595116, 'stop_loss': 1.06192, 'lots' : 18.52}",
#   '2023-10-11 21:15',
#   1.06084,
#   1852000,
#   -2000.16,
#   -0.1,
#   1867.46,
#   -0.2,
#   222.24,
#   0.01,
#   2000.16,
#   0.1),
#  (7,
#   'Exit Short',
#   'exit',
#   '2023-10-10 14:30',
#   1.05547,
#   2899000,
#   2464.15,
#   0.08,
#   3867.62,
#   0.25,
#   2464.15,
#   0.08,
#   173.94,
#   0.01),
#  (7,
#   'Entry Short',
#   "{'take_profit': 1.0554713, 'stop_loss': 1.05701, 'lots' : 28.99}",
#   '2023-10-10 14:10',
#   1.05632,
#   2899000,
#   2464.15,
#   0.08,
#   3867.62,
#   0.25,
#   2464.15,
#   0.08,
#   173.94,
#   0.01),
#  (6,
#   'Exit Long',
#   'exit',
#   '2023-10-10 00:55',
#   1.05352,
#   4255000,
#   -1999.85,
#   -0.04,
#   1403.47,
#   -0.2,
#   808.45,
#   0.02,
#   1999.85,
#   0.04),
#  (6,
#   'Entry Long',
#   "{'take_profit': 1.0545681, 'stop_loss': 1.05352, 'lots': 42.55}",
#   '2023-10-10 00:25',
#   1.05399,
#   4255000,
#   -1999.85,
#   -0.04,
#   1403.47,
#   -0.2,
#   808.45,
#   0.02,
#   1999.85,
#   0.04),
#  (5,
#   'Exit Short',
#   'exit',
#   '2023-10-05 16:50',
#   1.05029,
#   2439000,
#   2463.39,
#   0.1,
#   3403.32,
#   0.25,
#   2463.39,
#   0.1,
#   878.04,
#   0.03),
#  (5,
#   'Entry Short',
#   "{'take_profit': 1.0502914, 'stop_loss': 1.05212, 'lots' : 24.39}",
#   '2023-10-05 16:15',
#   1.0513,
#   2439000,
#   2463.39,
#   0.1,
#   3403.32,
#   0.25,
#   2463.39,
#   0.1,
#   878.04,
#   0.03),
#  (4,
#   'Exit Long',
#   'exit',
#   '2023-10-04 11:45',
#   1.04595,
#   2740000,
#   -2000.2,
#   -0.07,
#   939.93,
#   -0.2,
#   575.4,
#   0.02,
#   2000.2,
#   0.07),
#  (4,
#   'Entry Long',
#   "{'take_profit': 1.0475779, 'stop_loss': 1.04595, 'lots': 27.4}",
#   '2023-10-04 09:50',
#   1.04668,
#   2740000,
#   -2000.2,
#   -0.07,
#   939.93,
#   -0.2,
#   575.4,
#   0.02,
#   2000.2,
#   0.07),
#  (3,
#   'Exit Short',
#   'exit',
#   '2023-09-29 21:25',
#   1.05873,
#   1852000,
#   2463.16,
#   0.13,
#   2940.13,
#   0.25,
#   2463.16,
#   0.13,
#   1259.36,
#   0.06),
#  (3,
#   'Entry Short',
#   "{'take_profit': 1.0587316, 'stop_loss': 1.06114, 'lots' : 18.52}",
#   '2023-09-29 20:50',
#   1.06006,
#   1852000,
#   2463.16,
#   0.13,
#   2940.13,
#   0.25,
#   2463.16,
#   0.13,
#   1259.36,
#   0.06),
#  (2,
#   'Exit Short',
#   'exit',
#   '2023-09-28 22:05',
#   1.05556,
#   1183000,
#   -1999.27,
#   -0.16,
#   476.97,
#   -0.2,
#   272.09,
#   0.02,
#   1999.27,
#   0.16),
#  (2,
#   'Entry Short',
#   "{'take_profit': 1.0517913, 'stop_loss': 1.05556, 'lots' : 11.83}",
#   '2023-09-28 21:45',
#   1.05387,
#   1183000,
#   -1999.27,
#   -0.16,
#   476.97,
#   -0.2,
#   272.09,
#   0.02,
#   1999.27,
#   0.16),
#  (1,
#   'Exit Short',
#   'exit',
#   '2023-09-27 21:25',
#   1.05332,
#   2381000,
#   2476.24,
#   0.1,
#   2476.24,
#   0.25,
#   2476.24,
#   0.1,
#   1285.74,
#   0.05),
#  (1,
#   'Entry Short',
#   "{'take_profit': 1.0533268, 'stop_loss': 1.0552, 'lots' : 23.81}",
#   '2023-09-27 21:05',
#   1.05436,
#   2381000,
#   2476.24,
#   0.1,
#   2476.24,
#   0.25,
#   2476.24,
#   0.1,
#   1285.74,
#   0.05)]

# %%
(sdb := SQLDatabase.from_uri('sqlite:///../demo/sqlite_database.db', sample_rows_in_table_info=3))

# %%
sdb.get_usable_table_names()
# Out:
# ['tbl']

# %%
print(sdb.get_table_info())
# Out:
# CREATE TABLE tbl (
# 	"Trade #" BIGINT,
# 	"Type" VARCHAR,
# 	"Signal" VARCHAR,
# 	"Date/Time" VARCHAR,
# 	"Price USD" FLOAT,
# 	"Contracts" BIGINT,
# 	"Profit USD" FLOAT,
# 	"Profit %" FLOAT,
# 	"Cum. Profit USD" FLOAT,
# 	"Cum. Profit %" FLOAT,
# 	"Run-up USD" FLOAT,
# 	"Run-up %" FLOAT,
# 	"Drawdown USD" FLOAT,
# 	"Drawdown %" FLOAT
# )
#
# /*
# 3 rows from tbl table:
# Trade #	Type	Signal	Date/Time	Price USD	Contracts	Profit USD	Profit %	Cum. Profit USD	Cum. Profit %	Run-up USD	Run-up %	Drawdown USD	Drawdown %
# 23	Exit Long	Open	None	None	None	None	None	None	None	None	None	None	None
# 23	Entry Long	{'take_profit': 1.0703532, 'stop_loss': 1.06848, 'lots': 23.81}	2023-11-13 16:30	1.06932	None	None	None	None	None	None	None	None	None
# 22	Exit Long	exit	2023-11-10 22:50	1.06728	1852000	-2000.16	-0.1	9729.93	-0.2	203.72	0.01	2000.16	0.1
# */

# %%
# import os
# sconn.close()
# os.remove('../demo/sqlite_database.db')

# %% [markdown]
# ### Workaround: Pandas => SQAlchemy engine => SQLDatabase
#
# - [pandas.DataFrame.to_sql — pandas 2.1.3 documentation](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_sql.html)

# %%
import pandas as pd

# %%
(sqlite_engine := create_engine('sqlite:///../demo/test.db'))
# Out:
# Engine(sqlite:///../demo/test.db)

# %%
(df := pd.read_csv('../demo/demo.csv'))
# Out:
#     Trade #         Type                                             Signal  \
# 0        23    Exit Long                                               Open
# 1        23   Entry Long  {'take_profit': 1.0703532, 'stop_loss': 1.0684...
# 2        22    Exit Long                                               exit
# 3        22   Entry Long  {'take_profit': 1.0696884, 'stop_loss': 1.0672...
# 4        21    Exit Long                                               exit
# 5        21   Entry Long  {'take_profit': 1.0676857, 'stop_loss': 1.0663...
# 6        20   Exit Short                                               exit
# 7        20  Entry Short  {'take_profit': 1.06609605, 'stop_loss': 1.068...
# 8        19    Exit Long                                               exit
# 9        19   Entry Long  {'take_profit': 1.0679318, 'stop_loss': 1.0664...
# 10       18    Exit Long                                               exit
# 11       18   Entry Long  {'take_profit': 1.068731, 'stop_loss': 1.06717...
# 12       17   Exit Short                                               exit
# 13       17  Entry Short  {'take_profit': 1.0605748, 'stop_loss': 1.0633...
# 14       16   Exit Short                                               exit
# 15       16  Entry Short  {'take_profit': 1.0506124, 'stop_loss': 1.0553...
# 16       15    Exit Long                                               exit
# 17       15   Entry Long  {'take_profit': 1.0613861, 'stop_loss': 1.059,...
# 18       14    Exit Long                                               exit
# 19       14   Entry Long  {'take_profit': 1.0587472, 'stop_loss': 1.0573...
# 20       13   Exit Short                                               exit
# 21       13  Entry Short  {'take_profit': 1.0558588, 'stop_loss': 1.0568...
# 22       12   Exit Short                                               exit
# 23       12  Entry Short  {'take_profit': 1.063328, 'stop_loss': 1.06422...
# 24       11    Exit Long                                               exit
# 25       11   Entry Long  {'take_profit': 1.0537219, 'stop_loss': 1.0525...
# 26       10    Exit Long                                               exit
# 27       10   Entry Long  {'take_profit': 1.0539302, 'stop_loss': 1.0522...
# 28        9   Exit Short                                               exit
# 29        9  Entry Short  {'take_profit': 1.0514652, 'stop_loss': 1.0531...
# 30        8   Exit Short                                               exit
# 31        8  Entry Short  {'take_profit': 1.0595116, 'stop_loss': 1.0619...
# 32        7   Exit Short                                               exit
# 33        7  Entry Short  {'take_profit': 1.0554713, 'stop_loss': 1.0570...
# 34        6    Exit Long                                               exit
# 35        6   Entry Long  {'take_profit': 1.0545681, 'stop_loss': 1.0535...
# 36        5   Exit Short                                               exit
# 37        5  Entry Short  {'take_profit': 1.0502914, 'stop_loss': 1.0521...
# 38        4    Exit Long                                               exit
# 39        4   Entry Long  {'take_profit': 1.0475779, 'stop_loss': 1.0459...
# 40        3   Exit Short                                               exit
# 41        3  Entry Short  {'take_profit': 1.0587316, 'stop_loss': 1.0611...
# 42        2   Exit Short                                               exit
# 43        2  Entry Short  {'take_profit': 1.0517913, 'stop_loss': 1.0555...
# 44        1   Exit Short                                               exit
# 45        1  Entry Short  {'take_profit': 1.0533268, 'stop_loss': 1.0552...
#
#            Date/Time  Price USD  Contracts  Profit USD  Profit %  \
# 0                NaN        NaN        NaN         NaN       NaN
# 1   2023-11-13 16:30    1.06932        NaN         NaN       NaN
# 2   2023-11-10 22:50    1.06728  1852000.0    -2000.16     -0.10
# 3   2023-11-10 22:45    1.06836  1852000.0    -2000.16     -0.10
# 4   2023-11-10 17:45    1.06769  3390000.0     2474.70      0.07
# 5   2023-11-10 17:40    1.06696  3390000.0     2474.70      0.07
# 6   2023-11-08 22:30    1.06803  2312000.0    -2011.44     -0.08
# 7   2023-11-08 22:25    1.06716  2312000.0    -2011.44     -0.08
# 8   2023-11-08 21:25    1.06646  3030000.0    -1999.80     -0.06
# 9   2023-11-08 21:15    1.06712  3030000.0    -1999.80     -0.06
# 10  2023-11-08 02:15    1.06874  2857000.0     2485.59      0.08
# 11  2023-11-08 01:55    1.06787  2857000.0     2485.59      0.08
# 12  2023-11-03 14:35    1.06334  1613000.0    -2000.12     -0.12
# 13  2023-11-03 06:00    1.06210  1613000.0    -2000.12     -0.12
# 14  2023-11-02 03:05    1.05534   943000.0    -1999.16     -0.20
# 15  2023-11-02 02:15    1.05322   943000.0    -1999.16     -0.20
# 16  2023-10-30 23:05    1.06139  1869000.0     2467.08      0.12
# 17  2023-10-30 22:45    1.06007  1869000.0     2467.08      0.12
# 18  2023-10-30 19:40    1.05875  3125000.0     2468.75      0.07
# 19  2023-10-30 19:05    1.05796  3125000.0     2468.75      0.07
# 20  2023-10-30 15:25    1.05585  4545000.0     2499.75      0.05
# 21  2023-10-30 15:10    1.05640  4545000.0     2499.75      0.05
# 22  2023-10-24 20:00    1.06332  5000000.0     2500.00      0.05
# 23  2023-10-24 19:45    1.06382  5000000.0     2500.00      0.05
# 24  2023-10-16 19:55    1.05373  3774000.0     2490.84      0.06
# 25  2023-10-16 19:20    1.05307  3774000.0     2490.84      0.06
# 26  2023-10-16 16:45    1.05394  2703000.0     2486.76      0.09
# 27  2023-10-16 15:35    1.05302  2703000.0     2486.76      0.09
# 28  2023-10-13 20:20    1.05316  2632000.0    -2000.32     -0.07
# 29  2023-10-13 20:10    1.05240  2632000.0    -2000.32     -0.07
# 30  2023-10-11 21:25    1.06192  1852000.0    -2000.16     -0.10
# 31  2023-10-11 21:15    1.06084  1852000.0    -2000.16     -0.10
# 32  2023-10-10 14:30    1.05547  2899000.0     2464.15      0.08
# 33  2023-10-10 14:10    1.05632  2899000.0     2464.15      0.08
# 34  2023-10-10 00:55    1.05352  4255000.0    -1999.85     -0.04
# 35  2023-10-10 00:25    1.05399  4255000.0    -1999.85     -0.04
# 36  2023-10-05 16:50    1.05029  2439000.0     2463.39      0.10
# 37  2023-10-05 16:15    1.05130  2439000.0     2463.39      0.10
# 38  2023-10-04 11:45    1.04595  2740000.0    -2000.20     -0.07
# 39  2023-10-04 09:50    1.04668  2740000.0    -2000.20     -0.07
# 40  2023-09-29 21:25    1.05873  1852000.0     2463.16      0.13
# 41  2023-09-29 20:50    1.06006  1852000.0     2463.16      0.13
# 42  2023-09-28 22:05    1.05556  1183000.0    -1999.27     -0.16
# 43  2023-09-28 21:45    1.05387  1183000.0    -1999.27     -0.16
# 44  2023-09-27 21:25    1.05332  2381000.0     2476.24      0.10
# 45  2023-09-27 21:05    1.05436  2381000.0     2476.24      0.10
#
#     Cum. Profit USD  Cum. Profit %  Run-up USD  Run-up %  Drawdown USD  \
# 0               NaN            NaN         NaN       NaN           NaN
# 1               NaN            NaN         NaN       NaN           NaN
# 2           9729.93          -0.20      203.72      0.01       2000.16
# 3           9729.93          -0.20      203.72      0.01       2000.16
# 4          11730.09           0.25     2474.70      0.07        271.20
# 5          11730.09           0.25     2474.70      0.07        271.20
# 6           9255.39          -0.20      138.72      0.01       2011.44
# 7           9255.39          -0.20      138.72      0.01       2011.44
# 8          11266.83          -0.20      424.20      0.01       1999.80
# 9          11266.83          -0.20      424.20      0.01       1999.80
# 10         13266.63           0.25     2485.59      0.08        885.67
# 11         13266.63           0.25     2485.59      0.08        885.67
# 12         10781.04          -0.20      983.93      0.06       2000.12
# 13         10781.04          -0.20      983.93      0.06       2000.12
# 14         12781.16          -0.20     1471.08      0.15       1999.16
# 15         12781.16          -0.20     1471.08      0.15       1999.16
# 16         14780.32           0.24     2467.08      0.12        205.59
# 17         14780.32           0.24     2467.08      0.12        205.59
# 18         12313.24           0.24     2468.75      0.07       1937.50
# 19         12313.24           0.24     2468.75      0.07       1937.50
# 20          9844.49           0.25     2499.75      0.05        863.55
# 21          9844.49           0.25     2499.75      0.05        863.55
# 22          7344.74           0.25     2500.00      0.05       1750.00
# 23          7344.74           0.25     2500.00      0.05       1750.00
# 24          4844.74           0.25     2490.84      0.06        679.32
# 25          4844.74           0.25     2490.84      0.06        679.32
# 26          2353.90           0.25     2486.76      0.09       1811.01
# 27          2353.90           0.25     2486.76      0.09       1811.01
# 28          -132.86          -0.20      789.60      0.03       2000.32
# 29          -132.86          -0.20      789.60      0.03       2000.32
# 30          1867.46          -0.20      222.24      0.01       2000.16
# 31          1867.46          -0.20      222.24      0.01       2000.16
# 32          3867.62           0.25     2464.15      0.08        173.94
# 33          3867.62           0.25     2464.15      0.08        173.94
# 34          1403.47          -0.20      808.45      0.02       1999.85
# 35          1403.47          -0.20      808.45      0.02       1999.85
# 36          3403.32           0.25     2463.39      0.10        878.04
# 37          3403.32           0.25     2463.39      0.10        878.04
# 38           939.93          -0.20      575.40      0.02       2000.20
# 39           939.93          -0.20      575.40      0.02       2000.20
# 40          2940.13           0.25     2463.16      0.13       1259.36
# 41          2940.13           0.25     2463.16      0.13       1259.36
# 42           476.97          -0.20      272.09      0.02       1999.27
# 43           476.97          -0.20      272.09      0.02       1999.27
# 44          2476.24           0.25     2476.24      0.10       1285.74
# 45          2476.24           0.25     2476.24      0.10       1285.74
#
#     Drawdown %
# 0          NaN
# 1          NaN
# 2         0.10
# 3         0.10
# 4         0.01
# 5         0.01
# 6         0.08
# 7         0.08
# 8         0.06
# 9         0.06
# 10        0.03
# 11        0.03
# 12        0.12
# 13        0.12
# 14        0.20
# 15        0.20
# 16        0.01
# 17        0.01
# 18        0.06
# 19        0.06
# 20        0.02
# 21        0.02
# 22        0.03
# 23        0.03
# 24        0.02
# 25        0.02
# 26        0.06
# 27        0.06
# 28        0.07
# 29        0.07
# 30        0.10
# 31        0.10
# 32        0.01
# 33        0.01
# 34        0.04
# 35        0.04
# 36        0.03
# 37        0.03
# 38        0.07
# 39        0.07
# 40        0.06
# 41        0.06
# 42        0.16
# 43        0.16
# 44        0.05
# 45        0.05

# %%
df.to_sql('table', sqlite_engine)
# Out:
# 46

# %%
(sdb2 := SQLDatabase(sqlite_engine))

# %%
sdb2.get_usable_table_names()
# Out:
# ['table']

# %%
print(sdb2.get_table_info())
# Out:
# CREATE TABLE "table" (
# 	"index" BIGINT,
# 	"Trade #" BIGINT,
# 	"Type" TEXT,
# 	"Signal" TEXT,
# 	"Date/Time" TEXT,
# 	"Price USD" FLOAT,
# 	"Contracts" FLOAT,
# 	"Profit USD" FLOAT,
# 	"Profit %" FLOAT,
# 	"Cum. Profit USD" FLOAT,
# 	"Cum. Profit %" FLOAT,
# 	"Run-up USD" FLOAT,
# 	"Run-up %" FLOAT,
# 	"Drawdown USD" FLOAT,
# 	"Drawdown %" FLOAT
# )
#
# /*
# 3 rows from table table:
# index	Trade #	Type	Signal	Date/Time	Price USD	Contracts	Profit USD	Profit %	Cum. Profit USD	Cum. Profit %	Run-up USD	Run-up %	Drawdown USD	Drawdown %
# 0	23	Exit Long	Open	None	None	None	None	None	None	None	None	None	None	None
# 1	23	Entry Long	{'take_profit': 1.0703532, 'stop_loss': 1.06848, 'lots': 23.81}	2023-11-13 16:30	1.06932	None	None	None	None	None	None	None	None	None
# 2	22	Exit Long	exit	2023-11-10 22:50	1.06728	1852000.0	-2000.16	-0.1	9729.93	-0.2	203.72	0.01	2000.16	0.1
# */
